# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = np.zeros((512,700,3), np.uint8)

# %%
cv.rectangle(img,(100,400),(400,200),(249, 186, 6),-1)
cv.rectangle(img,(130,400),(200,300),(19, 100, 119),-1)
cv.rectangle(img,(220,300),(270,250),(19, 100, 119),-1)
cv.line(img,(70,220),(150,150),(0,0,255),5)
cv.line(img,(150,150),(355,150),(0,0,255),5)
cv.line(img,(355,150),(430,220),(0,0,255),5)

cv.rectangle(img,(500,400),(530,250),(113, 52, 19),-1)
cv.circle(img,(480,260), 40, (117, 160, 86), -1)
cv.circle(img,(450,220), 40, (117, 160, 86), -1)
cv.circle(img,(530,150), 40, (117, 160, 86), -1)
cv.circle(img,(540,200), 50, (117, 160, 86), -1)
cv.circle(img,(480,180), 50, (117, 160, 86), -1)
cv.circle(img,(550,250), 40, (117, 160, 86), -1)

plt.imshow(img)
plt.show()
